# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
        "solution_criteria: Key criteria evaluating the solution"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
dataset = generate_dataset()
with open('dataset.json', 'w') as f:
    json.dump(dataset, f, indent=2)

# %%
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Criteria you should use to evaluate the solution:
<criteria>
{test_case["solution_criteria"]}
</criteria>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
from statistics import mean

def run_prompt(test_case):
    """Merges the prompt and test case input, then returns the result"""
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Respond only with Python, JSON, or a plain Regex
* Do not add any comments or commentary or explanation
"""
    
    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)
    
    model_grade = grade_by_model(test_case, output)
    score = model_grade["score"]
    reasoning = model_grade["reasoning"]
    
    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []
    
    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")
    
    return results

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)

print(json.dumps(results, indent=2))
# Out:
# Average score: 5.666666666666667
# [
#   {
#     "output": "\nimport re\nimport json\n\ndef parse_cloudwatch_alarm(alarm_name):\n    pattern = r'^([a-z]+)-([a-z]+(?:-[a-z]+)*)-([a-z]+(?:-[a-z]+)*)-(high|low|warning|critical)$'\n    match = re.match(pattern, alarm_name)\n    \n    if match:\n        environment = match.group(1)\n        service_name = match.group(2)\n        metric_type = match.group(3)\n        severity = match.group(4)\n        \n        return {\n            \"environment\": environment,\n            \"service_name\": service_name,\n            \"metric_type\": metric_type,\n            \"severity\": severity\n        }\n    return None\n\nalarm_name = 'prod-payment-service-cpu-utilization-high'\nresult = parse_cloudwatch_alarm(alarm_name)\nprint(json.dumps(result, indent=2))\n",
#     "test_case": {
#       "task": "Parse an AWS CloudWatch alarm name and extract the environment, service name, and metric type using a regular expression. Example alarm name: 'prod-payment-service-cpu-utilization-high'",
#       "format": "regex",
#       "solution_criteria": "The regex should correctly capture three groups: environment (prod), service name (payment-service), and metric type (cpu-utilization-high). Should handle variations with different environment names and service naming conventions."
#     },
#     "score": 4,
#     "reasoning": "The solution demonstrates good regex fundamentals and structure, but fundamentally misinterprets the requirements. The criteria explicitly asks for metric_type to be 'cpu-utilization', not 'cpu-utilization-high'. The current regex produces metric_type='cpu-utilization' and severity='high' as separate fields, rather than treating them as a single metric_type group. Additionally, the hardcoded severity enum and rejection of numbers/uppercase reduce robustness for real-world AWS naming conventions."
#   },
#   {
#     "output": "\nimport json\nimport hashlib\nfrom datetime import datetime\n\ndef generate_cloudfront_config(bucket_name: str) -> str:\n    config = {\n        \"CallerReference\": hashlib.md5(f\"{bucket_name}-{datetime.utcnow().isoformat()}\".encode()).hexdigest(),\n        \"Comment\": f\"CloudFront distribution for {bucket_name}\",\n        \"Enabled\": True,\n        \"Origins\": {\n            \"Quantity\": 1,\n            \"Items\": [\n                {\n                    \"Id\": f\"{bucket_name}-origin\",\n                    \"DomainName\": f\"{bucket_name}.s3.amazonaws.com\",\n                    \"S3OriginConfig\": {\n                        \"OriginAccessIdentity\": \"\"\n                    }\n                }\n            ]\n        },\n        \"DefaultCacheBehavior\": {\n            \"TargetOriginId\": f\"{bucket_name}-origin\",\n            \"ViewerProtocolPolicy\": \"allow-all\",\n            \"TrustedSigners\": {\n                \"Enabled\": False,\n                \"Quantity\": 0\n            },\n            \"ForwardedValues\": {\n                \"QueryString\": False,\n                \"Cookies\": {\n                    \"Forward\": \"none\"\n                },\n                \"Headers\": {\n                    \"Quantity\": 0\n                }\n            },\n            \"MinTTL\": 0,\n            \"DefaultTTL\": 86400,\n            \"MaxTTL\": 31536000\n        },\n        \"CacheBehaviors\": {\n            \"Quantity\": 0,\n            \"Items\": []\n        }\n    }\n    return json.dumps(config, indent=2)\n",
#     "test_case": {
#       "task": "Write a Python function that takes an AWS S3 bucket name and returns a valid CloudFront distribution configuration JSON for that bucket. The function should return only the distribution config object.",
#       "format": "python",
#       "solution_criteria": "Function should return a valid CloudFront distribution configuration with proper S3 origin domain, default cache behavior, and enabled status. Should use appropriate AWS CloudFront schema structure."
#     },
#     "score": 5,
#     "reasoning": "The solution produces syntactically valid JSON that covers the basic CloudFront structure, but has several issues that would cause problems in production: missing required fields, outdated API patterns, and insecure default settings. The function meets the minimal criterion of returning a valid JSON structure, but the configuration itself contains security and API compliance issues that AWS best practices would flag."
#   },
#   {
#     "output": "\nimport json\n\npolicy = {\n    \"Version\": \"2012-10-17\",\n    \"Statement\": [\n        {\n            \"Effect\": \"Allow\",\n            \"Action\": [\n                \"s3:GetObject\",\n                \"s3:GetObjectVersion\"\n            ],\n            \"Resource\": \"arn:aws:s3:::company-data-lake/*\"\n        },\n        {\n            \"Effect\": \"Allow\",\n            \"Action\": [\n                \"s3:ListBucket\",\n                \"s3:GetBucketVersioning\"\n            ],\n            \"Resource\": \"arn:aws:s3:::company-data-lake\"\n        }\n    ]\n}\n\nprint(json.dumps(policy, indent=2))\n",
#     "test_case": {
#       "task": "Generate a JSON object representing an AWS IAM policy that grants read-only access to a specific S3 bucket named 'company-data-lake' and all objects within it.",
#       "format": "json",
#       "solution_criteria": "JSON should be a valid IAM policy with correct Version, Statement structure, proper Action array (s3:GetObject, s3:ListBucket), Resource ARNs for both bucket and objects, and Effect set to Allow."
#     },
#     "score": 8,
#     "reasoning": "The solution successfully generates a valid, functional IAM policy that meets the core requirement of granting read-only access to the S3 bucket and its objects. The policy structure is syntactically correct and the resource ARNs are properly formatted. The separation of bucket and object permissions follows AWS best practices. The inclusion of GetObjectVersion and GetBucketVersioning exceeds requirements but represents a reasonable interpretation of 'complete' read-only access. The policy is production-ready and secure."
#   }
# ]
