# %%
# %pip install anthropic python-dotenv
# Out:
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 26.1.1
# [notice] To update, run: /opt/homebrew/opt/python@3.11/bin/python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from anthropic import Anthropic

client = Anthropic()
model = "claude-haiku-4-5"

# %%
def add_user_messages(messages, text):
    user_message = {"role":"user", "content":text}
    messages.append(user_message)

def add_assistant_messages(messages, text):
    assistant_message = {"role":"assistant", "content":text}
    messages.append(assistant_message)

def chat(messages, system=None, temperature=1.0, stop_sequences=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature":temperature
    }
    if system:
        params["system"] = system
    if stop_sequences:
        params["stop_sequences"] = stop_sequences

 
    messages =  client.messages.create(**params)
    return messages.content[0].text

# %%
messages = []

add_user_messages(messages, "Define quantum computing in one sentence")

answer = chat(messages)

add_assistant_messages(messages, answer)

add_user_messages(messages, "Write another sentence")

answer = chat(messages)

answer
# Out:
# 'Unlike classical bits that exist as either 0 or 1, quantum bits (qubits) can exist in a superposition of both states simultaneously, allowing quantum computers to explore multiple solutions in parallel.'

# %%
messages = []

while True:
    user_input = input(">")
    print(">", user_input)
    add_user_messages(messages, user_input)
    answer = chat(messages)
    add_assistant_messages(messages, answer)
    print(answer)
# Out:
# >
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[12], line 7
#       3 while True:
#       4     user_input = input(">")
#       5     print(">", user_input)
#       6     add_user_messages(messages, user_input)
# ----> 7     answer = chat(messages)
#       8     add_assistant_messages(messages, answer)
#       9     print(answer)
#      10
#
# Cell In[10], line 19, in chat(messages, system, temperature)
#      15     }
#      16     if system:
#      17         params["system"] = system
#      18
# ---> 19     messages =  client.messages.create(**params)
#      20     return messages.content[0].text
#
# File /opt/homebrew/lib/python3.11/site-packages/anthropic/_utils/_utils.py:294, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     292             msg = f"Missing required argument: {quote(missing[0])}"
#     293     raise TypeError(msg)
# ...

# %%
messages = []

system = """
You are a patient math tutor.
Do not directly answer a student's questions.
Guide them to a solution step by step.
"""

add_user_messages(messages, "How do I solve 5x+3=2 for x?")
answer = chat(messages, system)

answer
# Out:
# "Great question! Let's work through this together step by step.\n\n**Step 1:** What do you think your goal should be when solving for x?\n\n(Hint: Think about what you want to end up with on one side of the equation.)\n\nOnce you answer that, we can figure out how to get there!"

# %%
messages = []

add_user_messages(messages, "Generate a one sentence movie idea")
answer = chat(messages, temperature=1.0)

answer
# Out:
# '# Movie Idea\n\nA washed-up stunt performer discovers that the only way to save her daughter from a dangerous crime syndicate is to pull off the most impossible stunt of her career—one that requires her to break the laws of physics itself.'

# %%
messages = []
add_user_messages(messages, "Write a 1 sentence description of a fake database")

# stream = client.messages.create(
#     model=model,
#     max_tokens=1000,
#     messages=messages,
#     stream=True
# )

# for event in stream:
#     print(event)

# with client.messages.stream(
#     model=model,
#     max_tokens=1000,
#     messages=messages
# ) as stream:
#     for text in stream.text_stream:
#         print(text, end="")

# %%
messages = []
add_user_messages(messages, "Generate a very short event bridge rule as json")
# add_assistant_messages(messages, "```json")

chat(messages)

# text = chat(messages, stop_sequences=["```"])
# Out:
# '```json\n{\n  "Name": "MyRule",\n  "EventBusName": "default",\n  "EventPattern": {\n    "source": ["aws.ec2"],\n    "detail-type": ["EC2 Instance State-change Notification"],\n    "detail": {\n      "state": ["running"]\n    }\n  },\n  "State": "ENABLED",\n  "Targets": [\n    {\n      "Arn": "arn:aws:sns:us-east-1:123456789012:MyTopic",\n      "Id": "1"\n    }\n  ]\n}\n```'

# %%
import json

# Clean up and parse the JSON
clean_json = json.loads(text.strip())
print(clean_json)
# Out:
# {'Name': 'MySimpleRule', 'EventBusName': 'default', 'EventPattern': {'source': ['aws.ec2'], 'detail-type': ['EC2 Instance State-change Notification'], 'detail': {'state': ['running']}}, 'State': 'ENABLED', 'Targets': [{'Arn': 'arn:aws:lambda:us-east-1:123456789012:function:MyFunction', 'Id': '1'}]}

# %%
messages = []

prompt = """
Generate three different sample AWS CLI commands. Each should be very short.
"""

add_user_messages(messages, prompt)
# add_assistant_messages(messages, "```bash")
add_assistant_messages(messages, "Here are all three commands in a single block without any comments:\n```bash")

text = chat(messages)
# text = chat(messages, stop_sequences=["```"])
text.strip()
# Out:
# 'aws s3 ls\naws ec2 describe-instances\naws lambda list-functions\n```'

# %%
from IPython.display import Markdown

Markdown(text)
# Out:
# aws s3 ls
# aws ec2 describe-instances
# aws lambda list-functions
# ```
